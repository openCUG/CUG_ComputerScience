# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,6))

threeD = [83,98,147]
Adversarial=[61,76,62]
video = [70,76,90]
Detection = [69,108,120]
Segmentation=[60,93,115]
Estimation=[55,65,87]
Point=[24,46,61]
Face = [36,46,54]
Human = [33,32,63]

plt.title('Keyword trends in three years')
plt.xlabel("Years",size=13)
plt.ylabel("The number of occurrences",size=13)
my_x_ticks = [2018,2019,2020] # 横坐标设置0,1,...,len(acc)-1,间隔为1
plt.xticks(my_x_ticks)

plt.plot(my_x_ticks,threeD,label="3D")
plt.plot(my_x_ticks,Adversarial,label="Adversarial")
plt.plot(my_x_ticks,video,label="Video")
plt.plot(my_x_ticks,Detection,label="Detection")
plt.plot(my_x_ticks,Segmentation,label="Segmentation")
plt.plot(my_x_ticks,Estimation,label="Estimation")
plt.plot(my_x_ticks,Point,label="Point")
plt.plot(my_x_ticks,Face,label="Face")
plt.plot(my_x_ticks,Human,label="Human")

plt.legend(fontsize=10)

plt.savefig("Trend.png",dpi=800)

plt.show()
