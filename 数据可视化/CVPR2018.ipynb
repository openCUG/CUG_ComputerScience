# %%
f2 = open("Data2018.txt","r")
lines = f2.readlines()

data=[]

times = 0

for i in lines:
    if len(i)<10:
        pass
    else:
        #print(i)
        times+=1
        data.append(i)

print("数据总行数：",len(lines))
print("有效行数：",times)
print("最终数据大小为：",len(data))
# Out:
# 数据总行数： 3914
# 有效行数： 1958
# 最终数据大小为： 1958

# %%
for i in data:
    print(i)
# Out:
# Embodied Question Answering
#
# Abhishek Das, Samyak Datta, Georgia Gkioxari, Stefan Lee, Devi Parikh, Dhruv Batra
#
# Learning by Asking Questions
#
# Ishan Misra, Ross Girshick, Rob Fergus, Martial Hebert, Abhinav Gupta, Laurens van der Maaten
#
# Finding Tiny Faces in the Wild With Generative Adversarial Network
#
# Yancheng Bai, Yongqiang Zhang, Mingli Ding, Bernard Ghanem
#
# Learning Face Age Progression: A Pyramid Architecture of GANs
#
# Hongyu Yang, Di Huang, Yunhong Wang, Anil K. Jain
#
# PairedCycleGAN: Asymmetric Style Transfer for Applying and Removing Makeup
#
# Huiwen Chang, Jingwan Lu, Fisher Yu, Adam Finkelstein
#
# GANerated Hands for Real-Time 3D Hand Tracking From Monocular RGB
#
# Franziska Mueller, Florian Bernard, Oleksandr Sotnychenko, Dushyant Mehta, Srinath Sridhar, Dan Casas, Christian Theobalt
#
# Learning Pose Specific Representations by Predicting Different Views
#
# Georg Poier, David Schinagl, Horst Bischof
#
# ...

# %%
index = 1

title=[]
author=[]

for i in data:
    if index % 2 != 0:
        title.append(i)
        index+=1
    elif index % 2 == 0:
        author.append(i)
        index+=1
        
print(len(title))
print(len(author))
# Out:
# 979
# 979

# %%
num = 1
for i in title:
    print(num)
    print(i)
    num+=1
# Out:
# 1
# Embodied Question Answering
#
# 2
# Learning by Asking Questions
#
# 3
# Finding Tiny Faces in the Wild With Generative Adversarial Network
#
# 4
# Learning Face Age Progression: A Pyramid Architecture of GANs
#
# 5
# PairedCycleGAN: Asymmetric Style Transfer for Applying and Removing Makeup
#
# 6
# GANerated Hands for Real-Time 3D Hand Tracking From Monocular RGB
#
# 7
# Learning Pose Specific Representations by Predicting Different Views
#
# 8
# Weakly and Semi Supervised Human Body Part Parsing via Pose-Guided Knowledge Transfer
#
# 9
# Person Transfer GAN to Bridge Domain Gap for Person Re-Identification
#
# 10
# Cross-Modal Deep Variational Hand Pose Estimation
#
# 11
# Disentangled Person Image Generation
#
# 12
# Super-FAN: Integrated Facial Landmark Localization and Super-Resolution of Real-World Low Resolution Faces in Arbitrary Poses With GANs
#
# 13
# Multistage Adversarial Losses for Pose-Based Human Image Synthesis
#
# 14
# Rotation Averaging and Strong Duality
#
# ...

# %%
# 导入jieba包
import jieba
#管理系统路径
import sys
import jieba.posseg as pseg

# %%
#删除空格和转置符号的实用案例

p = list(jieba.cut_for_search(title[0]))
print(p)
for i in p:
    if i == ' ':
        p.remove(i)
p.remove(p[len(p)-1])
print(p)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.786 seconds.
# Prefix dict has been built successfully.
# ['Embodied', ' ', 'Question', ' ', 'Answering', '\n']
# ['Embodied', 'Question', 'Answering']

# %%
D=[]
for i in title:
    p = list(jieba.cut_for_search(i))
    p.remove(p[len(p)-1])  #删除转置符号

    for n in p:
        if n == ' ':      #删除空格
            p.remove(n) 
    for n in p:
        if n == ':':      #删除冒号
            p.remove(n)
            
    for n in p:
        D.append(n)
            
print(len(D))
# Out:
# 9292

# %%
from collections import Counter

# %%
r = Counter(D)
print(r)
# Out:
# Counter({'-': 612, 'for': 384, 'Learning': 217, 'and': 196, 'With': 141, 'Image': 127, 'Deep': 122, 'of': 117, 'Networks': 112, 'Network': 95, 'to': 93, 'in': 92, '3D': 83, 'From': 81, 'Object': 74, 'Video': 70, 'A': 69, 'Detection': 69, 'Visual': 66, 'a': 63, 'Adversarial': 61, 'Segmentation': 60, 'Multi': 58, 'Neural': 57, 'the': 55, 'Estimation': 55, 'via': 54, 'Using': 52, 'by': 51, 'Recognition': 48, 'Pose': 47, 'Supervised': 44, 'Semantic': 44, 'Convolutional': 41, 'Person': 39, 'Single': 37, 'Face': 36, 'Aware': 36, 'Generative': 35, 'Based': 35, 'Feature': 35, 'Identification': 34, 'End': 34, 'Human': 33, 'Shape': 33, ',': 33, 'Re': 32, 'Shot': 32, 'Attention': 32, 'Scale': 31, 'Depth': 30, 'Unsupervised': 30, 'Weakly': 29, 'Action': 29, 'Images': 29, 'Domain': 28, 'Tracking': 27, 'Transfer': 26, 'Matching': 25, 'Videos': 25, 'Point': 24, 'Motion': 24, 'Localization': 23, 'Model': 23, 'Recurrent': 23, 'Fast': 23, 'Adaptation': 23, 'Generation': 22, 'Reconstruction': 22, 'Ques
# ...

# %%
import pandas as pd
df = pd.DataFrame(r.items(), columns=['key', 'times'])
df.sort_values("times",inplace=True)

dropDict=['-','for','on','via','and','A','a','From',
          'from','of','to','in','With','with','the','Based','Domain','Graph','Aware','Single','Shot',
          'Self','Using','using',',','by','End','Learning','Deep','Neural','Network','Networks','Image']

for i in dropDict:
    df = df.drop(df[df['key']==i].index)

# %%
tail = df.tail(20)

# %%
tail
# Out:
#                 key  times
# 54            Human     33
# 68   Identification     34
# 207         Feature     35
# 14       Generative     35
# 17             Face     36
# 61           Person     39
# 172   Convolutional     41
# 342        Semantic     44
# 53       Supervised     44
# 45             Pose     47
# 123     Recognition     48
# 73       Estimation     55
# 119           Multi     58
# 279    Segmentation     60
# 15      Adversarial     61
# 200          Visual     66
# 223       Detection     69
# 221           Video     70
# 122          Object     74
# 39               3D     83

# %%
x=[]
y=[]
for row in tail.iterrows():
    x.append(row[1][0])
    y.append(row[1][1])
    
len(x),len(y)
# Out:
# (20, 20)

# %%
import matplotlib.pyplot as plt
import numpy as np

yticks=np.arange(30,120,30)

k = np.arange(len(x))  #首先用第一个的长度作为横坐标
width = 0.1    #设置柱与柱之间的宽度

fig,ax = plt.subplots(figsize=(15, 7))
ax.set_axisbelow(True)
 
ax.bar(k,y,label='The number of occurrences of the keyword in the title',alpha = 1,color= 'orange')

ax.set_xticks(k)#将坐标设置在指定位置
ax.set_xticklabels(x,size=12)#将横坐标替换成
ax.set_yticks(yticks)

ax.set_xlabel('Keywords',size=15)
ax.set_ylabel('Times',size=20)

plt.xticks(rotation=60)
plt.legend(fontsize=17)
plt.grid(linestyle = '--',linewidth =1, color= 'gray',alpha = 0.4)
# plt.savefig("The number of occurrences of the keyword in the title 2018.png",dpi=800)
plt.show()

# %%
author[0][:-1]
# Out:
# 'Abhishek Das, Samyak Datta, Georgia Gkioxari, Stefan Lee, Devi Parikh, Dhruv Batra'

# %%
author1=[]

authors=[]

for i in author:
    ls = i[:-1].split(", ")
#     print(len(ls))
#     print(ls)
    author1.append(ls[0])
    for k in ls:
        authors.append(k)
#print(author1)

t = Counter(author1)
countAuthors = Counter(authors)
#print(t)

au = pd.DataFrame(t.items(), columns=['key', 'times'])
at = pd.DataFrame(countAuthors.items(), columns=['key', 'times'])
au.sort_values("times",inplace=True)
at.sort_values("times",inplace=True)
at.tail(20)
# Out:
#                         key  times
# 1018         Serge Belongie      8
# 823           Song-Chun Zhu      8
# 421          Larry S. Davis      8
# 128              Pascal Fua      8
# 297               Gang Wang      9
# 213              Huchuan Lu      9
# 241              Junjie Yan      9
# 168            Wanli Ouyang      9
# 326   Timothy M. Hospedales      9
# 124          Raquel Urtasun      9
# 325               Tao Xiang      9
# 77                Liang Lin      9
# 52            Bernt Schiele      9
# 449             Jiashi Feng     10
# 135            Chunhua Shen     10
# 250               Jan Kautz     11
# 166           Xiaogang Wang     13
# 366                 Wei Liu     13
# 51             Luc Van Gool     16
# 214         Ming-Hsuan Yang     17

# %%
x1=[]
y1=[]
for row in au.tail(20).iterrows():
    x1.append(row[1][0])
    y1.append(row[1][1])
    
len(x1),len(y1)
# Out:
# (20, 20)

# %%
x2=[]
y2=[]
for row in at.tail(20).iterrows():
    x2.append(row[1][0])
    y2.append(row[1][1])
    
len(x2),len(y2)
# Out:
# (20, 20)

# %%
yticks=np.arange(0,5)

k = np.arange(len(x))  #首先用第一个的长度作为横坐标
width = 0.1    #设置柱与柱之间的宽度

fig,ax = plt.subplots(figsize=(15, 7))
ax.set_axisbelow(True)
 
ax.bar(k,y1,label='Number of papers published as the first author',alpha = 1,color= 'orange')

ax.set_xticks(k)#将坐标设置在指定位置
ax.set_xticklabels(x1,size=12)#将横坐标替换成
ax.set_yticks(yticks)

ax.set_xlabel('AuthorName',size=15)
ax.set_ylabel('Quantity',size=15)

plt.xticks(rotation=60)
plt.legend(fontsize=13)
plt.grid(linestyle = '--',linewidth =1, color= 'gray',alpha = 0.4)
# plt.savefig("Number of papers published as the first author 2018.png",dpi=800)
plt.show()

# %%
yticks=np.arange(0,20,3)

k = np.arange(len(x2))  #首先用第一个的长度作为横坐标
width = 0.1    #设置柱与柱之间的宽度

fig,ax = plt.subplots(figsize=(15, 7))
ax.set_axisbelow(True)
 
ax.bar(k,y2,label='Number of articles the author has participated in',alpha = 1,color= 'orange')

ax.set_xticks(k)#将坐标设置在指定位置
ax.set_xticklabels(x2,size=12)#将横坐标替换成
ax.set_yticks(yticks)

ax.set_xlabel('AuthorName',size=15)
ax.set_ylabel('Quantity',size=15)

plt.xticks(rotation=60)
plt.legend(fontsize=13)
plt.grid(linestyle = '--',linewidth =1, color= 'gray',alpha = 0.4)
# plt.savefig("Number of articles the author has participated in 2018.png",dpi=800)
plt.show()

# %%
np=df.key
string_paper = ' '.join(D)
import numpy as np
from PIL import Image
import re
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS
import  matplotlib.pyplot as plt

sw = {'-','for','on','via','and','A','a','From','Image','Deep','Network',
          'from','of','to','in','With','with','the','Based','Networks',
          'Self','Using','using',',','by','End','Learning'}


my_wordcloud = WordCloud(scale=8,stopwords=sw,background_color='white',max_words = 100,
                         max_font_size = 60,random_state=20).generate(string_paper) 
#显示生成的词云 
plt.imshow(my_wordcloud)
plt.axis("off") 
plt.show() 

#保存生成的图片
my_wordcloud.to_file('Keywords wordcloud 2018.png')
